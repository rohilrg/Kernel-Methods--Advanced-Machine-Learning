# %%
from Kernel_PCA import swiss_roll_dataset,classic_pca,kernel_pca,plot_graph
import matplotlib.pyplot as plt
import time
import numpy as np

# %%
X,color = swiss_roll_dataset(number_of_samples=1200,plot=True)

# %% [markdown]
# ## Classic PCA implementation

# %%
X_transformed_2=classic_pca(X,color,n_components=2)

# %%
X_transformed_1=classic_pca(X,color,n_components=1)

# %% [markdown]
# ## Kernel PCA Implementation

# %%
for gamma in range(1,10,2):
    start_time = time.time()
    gamma= gamma/100
    X_pc = kernel_pca(X, n_components=2,type_of_kernel='rbf',gamma=gamma)
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pc[:, 0], X_pc[:, 1], c=color, cmap=plt.cm.rainbow)
    plt.title('First 2 principal components after RBF Kernel PCA')
    plt.text(-0.14, 0.14, 'gamma = {}'.format(gamma), fontsize=12)
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.show()
    print("The running time for RBF Kernel with",gamma,'gamma is %s'%(time.time()-start_time),'seconds')
# Out:
# (1200, 1200)
# The running time for RBF Kernel with 0.01 gamma is 0.6980178356170654 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.03 gamma is 0.7313756942749023 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.05 gamma is 0.8518571853637695 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.07 gamma is 0.8212101459503174 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.09 gamma is 0.7856624126434326 seconds

# %%
for gamma in range(1,10,2):
    start_time = time.time()
    gamma= gamma/100
    X_pc = kernel_pca(X, n_components=1,type_of_kernel='rbf',gamma=gamma)

    plt.figure(figsize=(8,6))
    plt.scatter(X_pc[:,0], np.zeros((X_pc.shape[0],1)), c=color.reshape((X_pc.shape[0],1)), cmap=plt.cm.rainbow)

    plt.text(-0.125, 0.007, 'gamma = {}'.format(gamma), fontsize=12)
    plt.title('First principal component after RBF Kernel PCA')
    plt.xlabel('PC1')
    plt.show()
    print("The running time for RBF Kernel with",gamma,'gamma is %s'%(time.time()-start_time),'seconds')
# Out:
# (1200, 1200)
# The running time for RBF Kernel with 0.01 gamma is 0.6702256202697754 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.03 gamma is 0.7599596977233887 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.05 gamma is 0.7961630821228027 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.07 gamma is 0.765470027923584 seconds
# (1200, 1200)
# The running time for RBF Kernel with 0.09 gamma is 0.7493846416473389 seconds

# %% [markdown]
# ### K-PCA with Polynomial Kernel

# %%
for poly_const in np.array([0.01,0.1,1,10,100,1000,10000,100000]):
    start_time = time.time()
    X_pc = kernel_pca(X, n_components=2,type_of_kernel='poly',poly_constant=poly_const)
    plt.figure(figsize=(8, 6))
    plt.scatter(X_pc[:, 0], X_pc[:, 1], c=color, cmap=plt.cm.rainbow)
    plt.title('First 2 principal components after Polynomial Kernel PCA')
    plt.text(-0.14, 0.14, 'poly_constant = {}'.format(poly_const), fontsize=12)
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.show()
    print("The running time for RBF Kernel with",poly_const,'polynomial kernel constant is %s'%(time.time()-start_time),'seconds')
# Out:
# The running time for RBF Kernel with 0.01 polynomial kernel constant is 1.9263598918914795 seconds
# The running time for RBF Kernel with 0.1 polynomial kernel constant is 2.014169931411743 seconds
# The running time for RBF Kernel with 1.0 polynomial kernel constant is 1.9623630046844482 seconds
# The running time for RBF Kernel with 10.0 polynomial kernel constant is 2.0358009338378906 seconds
# The running time for RBF Kernel with 100.0 polynomial kernel constant is 2.000016927719116 seconds
# The running time for RBF Kernel with 1000.0 polynomial kernel constant is 1.9260590076446533 seconds
# The running time for RBF Kernel with 10000.0 polynomial kernel constant is 2.879387855529785 seconds
# The running time for RBF Kernel with 100000.0 polynomial kernel constant is 2.718257188796997 seconds

# %% [markdown]
# #### K-PCA with Sigmoid Kernel

# %%
for sigmoid_const in np.array([1,10,20]):
    for sigmoid_alpha in np.array([0.001,0.01]):   
        start_time = time.time()
        X_pc = kernel_pca(X, n_components=2,type_of_kernel='sigmoid',sigmoid_alpha=sigmoid_alpha,sigmoid_constant=sigmoid_const)
        plt.figure(figsize=(8, 6))
        plt.scatter(X_pc[:, 0], X_pc[:, 1], c=color, cmap=plt.cm.rainbow)
        plt.title('First 2 principal components after RBF Kernel PCA')
        plt.text(-0.14, 0.14, ('sigmoid_constant = {}'.format(sigmoid_const),'sigmoid_alpha={}'.format(sigmoid_alpha)), fontsize=12)
        plt.xlabel('PC1')
        plt.ylabel('PC2')
        plt.show()
        print("The running time for RBF Kernel with",sigmoid_const,'sigmoid kernel constant and',sigmoid_alpha,'sigmoid kernel alpha is %s'%(time.time()-start_time),'seconds')
# Out:
# The running time for RBF Kernel with 1 sigmoid kernel constant and 0.001 sigmoid kernel alpha is 2.744168519973755 seconds
# The running time for RBF Kernel with 1 sigmoid kernel constant and 0.01 sigmoid kernel alpha is 2.7099552154541016 seconds
# The running time for RBF Kernel with 10 sigmoid kernel constant and 0.001 sigmoid kernel alpha is 2.8961141109466553 seconds
# The running time for RBF Kernel with 10 sigmoid kernel constant and 0.01 sigmoid kernel alpha is 2.828298330307007 seconds
# The running time for RBF Kernel with 20 sigmoid kernel constant and 0.001 sigmoid kernel alpha is 2.6507344245910645 seconds
# The running time for RBF Kernel with 20 sigmoid kernel constant and 0.01 sigmoid kernel alpha is 2.7181923389434814 seconds
