# %%
from SVDD_definitions import one_class_dataset_generator,svdd

# %%
X_array,X=one_class_dataset_generator(n_samples=300,number_of_outliers=10,plot=True)

# %%
for i in range(1,6,1):
    i= i/10
    svdd(X_array,X,Constant_for_SVDD=i)
# Out:
# Problem Status: optimal
# The number of support vectors are 2
# Problem Status: optimal
# The number of support vectors are 3
# Problem Status: optimal
# The number of support vectors are 2
# Problem Status: optimal
# The number of support vectors are 3
# Problem Status: optimal
# The number of support vectors are 3
